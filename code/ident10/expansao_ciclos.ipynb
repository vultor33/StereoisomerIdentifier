# %%
import sympy
import pandas as pd

# %%
# PPY-6
indice_ciclos_rot = (x1**6 + x1*x5 + x1*x5 + x1*x5 + x1*x5)

indice_ciclos_completo = (indice_ciclos_rot + x1*x1*x2*x2 
                          + x1*x2*x1*x2 + x1*x2*x2*x1 + x1*x2*x2*x1 
                          + x1*x2*x2*x1)
coeficientes = coeficientes_6
termo_rot = 1/5
termo_comp = 1/10

# %%
# JBCSAPR-10
indice_ciclos_rot = (x1**10 + x4*x4*x1*x1 + x2*x2*x2*x2*x1*x1
                    + x4*x4*x1*x1 + x2*x2*x2*x2*x2 + x2*x2*x2*x2*x2
                    + x2*x2*x2*x2*x2 + x2*x2*x2*x2*x2)

indice_ciclos_completo = (indice_ciclos_rot + x2*x2*x2*x1*x1*x1*x1
                         + x2*x2*x1*x2*x1*x1*x1 + x2*x1*x2*x2*x1*x1*x1
                         + x1*x2*x2*x2*x1*x1*x1 + x8*x2 + x8*x2 + x8*x2
                         + x8*x2)
coeficientes = coeficientes_10
termo_rot = 1/8
termo_comp = 1/16

# %%
# JSPC-10
indice_ciclos_rot = (x1**10 + x2*x2*x2*x2*x2)

indice_ciclos_completo = (indice_ciclos_rot + x2*x1*x2*x2*x1*x2
                         + x2*x2*x2*x1*x1*x1*x1)
coeficientes = coeficientes_10
termo_rot = 1/2
termo_comp = 1/4

# %%
# TD-10
indice_ciclos_rot = (x1**10 + x2*x2*x2*x2*x2)

indice_ciclos_completo = (indice_ciclos_rot + x2*x2*x2*x2*x1*x1
                         + x2*x2*x1*x1*x1*x1*x2)
coeficientes = coeficientes_10
termo_rot = 1/2
termo_comp = 1/4

# %% [markdown]
# # Calcular os coeficientes

# %%
tabela = {}
tabela['0formula'] = []
tabela['1total'] = []
tabela['2chiral'] = []
tabela['3achiral'] = []
expansao_rot = expansao_polinomios(indice_ciclos_rot)
expansao_completo = expansao_polinomios(indice_ciclos_completo)

for coef in coeficientes:
    total = int(termo_rot * expansao_rot.coeff(coef,1))
    comp = int(termo_comp * expansao_completo.coeff(coef,1))
    chiral = 2 * (total - comp)
    achiral = total - chiral
    tabela['0formula'].append(str(coef))
    tabela['1total'].append(total)
    tabela['2chiral'].append(chiral)
    tabela['3achiral'].append(achiral)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-67f135bcb83e> in <module>
#       4 tabela['2chiral'] = []
#       5 tabela['3achiral'] = []
# ----> 6 expansao_rot = expansao_polinomios(indice_ciclos_rot)
#       7 expansao_completo = expansao_polinomios(indice_ciclos_completo)
#       8
#
# D:\ARTIGOS\ARTIGOS_SIMAS\codigos\StereoisomerIdentifier\code\ident10\expansao_ciclos.py in expansao_polinomios(indice_ciclos)
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\polys\polytools.py in __new__(cls, rep, *gens, **args)
#     160                 return cls._from_poly(rep, opt)
#     161             else:
# --> 162                 return cls._from_expr(rep, opt)
#     163
#     164     # Poly does not pass its args to Basic.__new__ to be stored in _args so we
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\polys\polytools.py in _from_expr(cls, rep, opt)
#     289     def _from_expr(cls, rep, opt):
#     290         """Construct a polynomial from an expression. """
# --> 291         rep, opt = _dict_from_expr(rep, opt)
#     292         return cls._from_dict(rep, opt)
#     293
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\polys\polyutils.py in _dict_from_expr(expr, opt)
#     367         rep, gens = _dict_from_expr_if_gens(expr, opt)
#     368     else:
# --> 369         rep, gens = _dict_from_expr_no_gens(expr, opt)
#     370
#     371     return rep, opt.clone({'gens': gens})
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\polys\polyutils.py in _dict_from_expr_no_gens(expr, opt)
#     310 def _dict_from_expr_no_gens(expr, opt):
#     311     """Transform an expression into a multinomial form and figure out generators. """
# --> 312     (poly,), gens = _parallel_dict_from_expr_no_gens((expr,), opt)
#     313     return poly, gens
#     314
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\polys\polyutils.py in _parallel_dict_from_expr_no_gens(exprs, opt)
#     259                 else:
#     260                     if opt.series is False:
# --> 261                         base, exp = decompose_power(factor)
#     262
#     263                         if exp < 0:
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\core\exprtools.py in decompose_power(expr)
#     238
#     239     """
# --> 240     base, exp = expr.as_base_exp()
#     241
#     242     if exp.is_Number:
#
# D:\ANACONDA\envs\StereoIdent\lib\site-packages\sympy\core\expr.py in as_base_exp(self)
#    1974     def as_base_exp(self):
#    1975         # a -> b ** e
# -> 1976         return self, S.One
#    1977
#    1978     def as_coeff_mul(self, *deps, **kwargs):
#
# KeyboardInterrupt:

# %%
pd.DataFrame(tabela).to_csv('resultado.csv',sep=';',index=False)

# %%
str(termo_rot * expansao_rot)
# Out:
# '1.0*a**10 + 2.0*a**9*b + 2.0*a**9*c + 2.0*a**9*d + 2.0*a**9*e + 2.0*a**9*f + 2.0*a**9*g + 2.0*a**9*h + 2.0*a**9*i + 2.0*a**9*j + 9.0*a**8*b**2 + 12.0*a**8*b*c + 12.0*a**8*b*d + 12.0*a**8*b*e + 12.0*a**8*b*f + 12.0*a**8*b*g + 12.0*a**8*b*h + 12.0*a**8*b*i + 12.0*a**8*b*j + 9.0*a**8*c**2 + 12.0*a**8*c*d + 12.0*a**8*c*e + 12.0*a**8*c*f + 12.0*a**8*c*g + 12.0*a**8*c*h + 12.0*a**8*c*i + 12.0*a**8*c*j + 9.0*a**8*d**2 + 12.0*a**8*d*e + 12.0*a**8*d*f + 12.0*a**8*d*g + 12.0*a**8*d*h + 12.0*a**8*d*i + 12.0*a**8*d*j + 9.0*a**8*e**2 + 12.0*a**8*e*f + 12.0*a**8*e*g + 12.0*a**8*e*h + 12.0*a**8*e*i + 12.0*a**8*e*j + 9.0*a**8*f**2 + 12.0*a**8*f*g + 12.0*a**8*f*h + 12.0*a**8*f*i + 12.0*a**8*f*j + 9.0*a**8*g**2 + 12.0*a**8*g*h + 12.0*a**8*g*i + 12.0*a**8*g*j + 9.0*a**8*h**2 + 12.0*a**8*h*i + 12.0*a**8*h*j + 9.0*a**8*i**2 + 12.0*a**8*i*j + 9.0*a**8*j**2 + 16.0*a**7*b**3 + 46.0*a**7*b**2*c + 46.0*a**7*b**2*d + 46.0*a**7*b**2*e + 46.0*a**7*b**2*f + 46.0*a**7*b**2*g + 46.0*a**7*b**2*h + 46.0*a**7*b**2*i + 46.0*a**7*b**2*j + 46.0*a**7*b*c**2 + 90.0*a**7*b*c*d + 90.0*a**7*b*c*e + 90.0*a**7*b*c*f + 90.0*a**7*b*c*g + 90.0*a**7*b*c*h + 90.0*a**7*b*c*i + 90.0*a**7*b*c*j + 46.0*a**7*b*d**2 + 90.0*a**7*b*d*e + 90.0*a**7*b*d*f + 90.0*a**7*b*d*g + 90.0*a**7*b*d*h + 90.0*a**7*b*d*i + 90.0*a**7*b*d*j + 46.0*a**7*b*e**2 + 90.0*a**7*b*e*f + 90.0*a**7*b*e*g + 90.0*a**7*b*e*h + 90.0*a**7*b*e*i + 90.0*a**7*b*e*j + 46.0*a**7*b*f**2 + 90.0*a**7*b*f*g + 90.0*a**7*b*f*h + 90.0*a**7*b*f*i + 90.0*a**7*b*f*j + 46.0*a**7*b*g**2 + 90.0*a**7*b*g*h + 90.0*a**7*b*g*i + 90.0*a**7*b*g*j + 46.0*a**7*b*h**2 + 90.0*a**7*b*h*i + 90.0*a**7*b*h*j + 46.0*a**7*b*i**2 + 90.0*a**7*b*i*j + 46.0*a**7*b*j**2 + 16.0*a**7*c**3 + 46.0*a**7*c**2*d + 46.0*a**7*c**2*e + 46.0*a**7*c**2*f + 46.0*a**7*c**2*g + 46.0*a**7*c**2*h + 46.0*a**7*c**2*i + 46.0*a**7*c**2*j + 46.0*a**7*c*d**2 + 90.0*a**7*c*d*e + 90.0*a**7*c*d*f + 90.0*a**7*c*d*g + 90.0*a**7*c*d*h + 90.0*a**7*c*d*i + 90.0*a**7*c*d*j + 46.0*a**7*c*e**2 + 90.0*a**7*c*e*f + 90.0*a**7*c*e*g + 90.0*a**7*c*e*h + 90.0*a**7*c*e*i + 90.0*a**7*c*e*j + 46.0*a**7*c*f**2 + 90.0*a**7*c*f*g + 90.0*a**7*c*f*h + 90.0*a**7*c*f*i + 90.0*a**7*c*f*j + 46.0*a**7*c*g**2 + 90.0*a**7*c*g*h + 90.0*a**7*c*g*i + 90.0*a**7*c*g*j + 46.0*a**7*c*h**2 + 90.0*a**7*c*h*i + 90.0*a**7*c*h*j + 46.0*a**7*c*i**2 + 90.0*a**7*c*i*j + 46.0*a**7*c*j**2 + 16.0*a**7*d**3 + 46.0*a**7*d**2*e + 46.0*a**7*d**2*f + 46.0*a**7*d**2*g + 46.0*a**7*d**2*h + 46.0*a**7*d**2*i + 46.0*a**7*d**2*j + 46.0*a**7*d*e**2 + 90.0*a**7*d*e*f + 90.0*a**7*d*e*g + 90.0*a**7*d*e*h + 90.0*a**7*d*e*i + 90.0*a**7*d*e*j + 46.0*a**7*d*f**2 + 90.0*a**7*d*f*g + 90.0*a**7*d*f*h + 90.0*a**7*d*f*i + 90.0*a**7*d*f*j + 46.0*a**7*d*g**2 + 90.0*a**7*d*g*h + 90.0*a**7*d*g*i + 90.0*a**7*d*g*j + 46.0*a**7*d*h**2 + 90.0*a**7*d*h*i + 90.0*a**7*d*h*j + 46.0*a**7*d*i**2 + 90.0*a**7*d*i*j + 46.0*a**7*d*j**2 + 16.0*a**7*e**3 + 46.0*a**7*e**2*f + 46.0*a**7*e**2*g + 46.0*a**7*e**2*h + 46.0*a**7*e**2*i + 46.0*a**7*e**2*j + 46.0*a**7*e*f**2 + 90.0*a**7*e*f*g + 90.0*a**7*e*f*h + 90.0*a**7*e*f*i + 90.0*a**7*e*f*j + 46.0*a**7*e*g**2 + 90.0*a**7*e*g*h + 90.0*a**7*e*g*i + 90.0*a**7*e*g*j + 46.0*a**7*e*h**2 + 90.0*a**7*e*h*i + 90.0*a**7*e*h*j + 46.0*a**7*e*i**2 + 90.0*a**7*e*i*j + 46.0*a**7*e*j**2 + 16.0*a**7*f**3 + 46.0*a**7*f**2*g + 46.0*a**7*f**2*h + 46.0*a**7*f**2*i + 46.0*a**7*f**2*j + 46.0*a**7*f*g**2 + 90.0*a**7*f*g*h + 90.0*a**7*f*g*i + 90.0*a**7*f*g*j + 46.0*a**7*f*h**2 + 90.0*a**7*f*h*i + 90.0*a**7*f*h*j + 46.0*a**7*f*i**2 + 90.0*a**7*f*i*j + 46.0*a**7*f*j**2 + 16.0*a**7*g**3 + 46.0*a**7*g**2*h + 46.0*a**7*g**2*i + 46.0*a**7*g**2*j + 46.0*a**7*g*h**2 + 90.0*a**7*g*h*i + 90.0*a**7*g*h*j + 46.0*a**7*g*i**2 + 90.0*a**7*g*i*j + 46.0*a**7*g*j**2 + 16.0*a**7*h**3 + 46.0*a**7*h**2*i + 46.0*a**7*h**2*j + 46.0*a**7*h*i**2 + 90.0*a**7*h*i*j + 46.0*a**7*h*j**2 + 16.0*a**7*i**3 + 46.0*a**7*i**2*j + 46.0*a**7*i*j**2 + 16.0*a**7*j**3 + 33.0*a**6*b**4 + 106.0*a**6*b**3*c + 106.0*a**6*b**3*d + 106.0*a**6*b**3*e + 106.0*a**6*b**3*f + 106.0*a**6*b**3*g +  ...

# %% [markdown]
# # Mostar os indices de ciclos

# %%
x1, x2, x3, x4, x5, x6, x7, x8, x9, x10 = sympy.symbols('x1 x2 x3 x4 x5 x6 x7 x8 x9 x10')

# %%
# JBCSAPR-10
indice_ciclos_rot = (x1**10 + x4*x4*x1*x1 + x2*x2*x2*x2*x1*x1
                    + x4*x4*x1*x1 + x2*x2*x2*x2*x2 + x2*x2*x2*x2*x2
                    + x2*x2*x2*x2*x2 + x2*x2*x2*x2*x2)

indice_ciclos_completo = (indice_ciclos_rot + x2*x2*x2*x1*x1*x1*x1
                         + x2*x2*x1*x2*x1*x1*x1 + x2*x1*x2*x2*x1*x1*x1
                         + x1*x2*x2*x2*x1*x1*x1 + x8*x2 + x8*x2 + x8*x2
                         + x8*x2)
coeficientes = coeficientes_10
termo_rot = 1/8
termo_comp = 1/16

# %%
# JSPC-10
indice_ciclos_rot = (x1**10 + x2*x2*x2*x2*x2)

indice_ciclos_completo = (indice_ciclos_rot + x2*x1*x2*x2*x1*x2
                         + x2*x2*x2*x1*x1*x1*x1)
coeficientes = coeficientes_10
termo_rot = 1/2
termo_comp = 1/4

# %%
indice_ciclos_rot
# Out:
#   10     5
# x₁   + x₂

# %%
indice_ciclos_completo
# Out:
#   10     4   3     2   4     5
# x₁   + x₁ ⋅x₂  + x₁ ⋅x₂  + x₂
